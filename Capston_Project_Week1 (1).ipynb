# %% [markdown]
# # This repository is used solely for Coursera_Capston_Project purpose

# %% [markdown]
# Name=Sumeet Adhav,
# Week=1

# %%
import pandas as pd
import Numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-91d2c96e0f92> in <module>
#       1 import pandas as pd
# ----> 2 import Numpy as np
#
# ModuleNotFoundError: No module named 'Numpy'
